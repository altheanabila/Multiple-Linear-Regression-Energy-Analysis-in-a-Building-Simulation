# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_excel('Data1.xlsx')

# %%
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84

# %%
import statsmodels.api as sn

# %%
X_multi = df.drop("Y1",axis=1)

# %%
X_multi.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0

# %%
y_multi = df['Y1']

# %%
y_multi.head()
# Out:
# 0    15.55
# 1    15.55
# 2    15.55
# 3    15.55
# 4    20.84
# Name: Y1, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const    X1     X2     X3      X4   X5  X6   X7  X8
# 0    1.0  0.98  514.5  294.0  110.25  7.0   2  0.0   0
# 1    1.0  0.98  514.5  294.0  110.25  7.0   3  0.0   0
# 2    1.0  0.98  514.5  294.0  110.25  7.0   4  0.0   0
# 3    1.0  0.98  514.5  294.0  110.25  7.0   5  0.0   0
# 4    1.0  0.90  563.5  318.5  122.50  7.0   2  0.0   0

# %%
 lm_multi = sn.OLS(y_multi, X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     Y1   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     1187.
# Date:                Sat, 15 May 2021   Prob (F-statistic):               0.00
# Time:                        01:22:53   Log-Likelihood:                -1912.5
# No. Observations:                 768   AIC:                             3841.
# Df Residuals:                     760   BIC:                             3878.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         84.0145     19.034      4.414      0.000      46.650     121.379
# ...

# %%
##Fit the algorithm
from sklearn.linear_model import LinearRegression
Regressor = LinearRegression()



## Prepare the data for Visualization

Regressor.fit(X,Y)

x_surf, y_surf = np.meshgrid(np.linspace(df.X1.min(), df.X1.max(), 100),np.linspace(df.X2.min(), df.X2.max(), 100))
onlyX = pd.DataFrame({'X1': x_surf.ravel(), 'X2': y_surf.ravel()})
fittedY=Regressor.predict(onlyX)


# Visualize the Data for Multiple Linear Regression
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(20,10))
### Set figure size
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['X1'],df['X2'],df['Y1'],c='red', marker='o', alpha=0.5)
ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape), color='b', alpha=0.3)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Y1')
plt.show()

# %%
##Fit the algorithm
from sklearn.linear_model import LinearRegression
Regressor = LinearRegression()



## Prepare the data for Visualization

Regressor.fit(X,Y)

x_surf, y_surf = np.meshgrid(np.linspace(df.X3.min(), df.X3.max(), 100),np.linspace(df.X4.min(), df.X4.max(), 100))
onlyX = pd.DataFrame({'X3': x_surf.ravel(), 'X4': y_surf.ravel()})
fittedY=Regressor.predict(onlyX)


# Visualize the Data for Multiple Linear Regression
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(20,10))
### Set figure size
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['X3'],df['X4'],df['Y1'],c='red', marker='o', alpha=0.5)
ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape), color='b', alpha=0.3)
ax.set_xlabel('X3')
ax.set_ylabel('X4')
ax.set_zlabel('Y1')
plt.show()

# %%
##Fit the algorithm
from sklearn.linear_model import LinearRegression
Regressor = LinearRegression()



## Prepare the data for Visualization

Regressor.fit(X,Y)

x_surf, y_surf = np.meshgrid(np.linspace(df.X1.min(), df.X1.max(), 100),np.linspace(df.X4.min(), df.X4.max(), 100))
onlyX = pd.DataFrame({'X1': x_surf.ravel(), 'X4': y_surf.ravel()})
fittedY=Regressor.predict(onlyX)


# Visualize the Data for Multiple Linear Regression
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(20,10))
### Set figure size
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['X1'],df['X4'],df['Y1'],c='red', marker='o', alpha=0.5)
ax.plot_surface(x_surf,y_surf,fittedY.reshape(x_surf.shape), color='b', alpha=0.3)
ax.set_xlabel('X1')
ax.set_ylabel('X4')
ax.set_zlabel('Y1')
plt.show()
